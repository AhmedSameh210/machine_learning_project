# %%
pip install beautifulsoup4
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
html_source="""Write here the HTML Body"""

# %%
soup = BeautifulSoup(html_source, 'html.parser')

# %%
table = soup.find('tbody')

# %%
def Convert_htmlTableToCsv(table):
    headers = [header.text.strip() for header in table.find_all('th')]
    rows = []
    for row in table.find_all('tr'):
        cells = row.find_all('td')
        if cells:
            rows.append([cell.text.strip() for cell in cells])
    df=pd.DataFrame(rows).drop([2],axis=1)
    return df

def concat(oldDF,NewDf)
    df=pd.concat([NewDf,oldDF],axis=0).reset_index().drop(["index"],axis=1)
    return df

# %%
"Manually extract the HTML code from the tables and use these functions to convert it into CSV format."
